# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
scmDataFm = pd.read_csv('/workspaces/test-devcontainer-python/day01/supply_chain_data.csv')
scmDataFm.head(100)
#scmDataFm.describe()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006           NaN                      802
# 1      skincare   SKU1  14.843523          95.0                      736
# 2      haircare   SKU2  11.319683          34.0                        8
# 3      skincare   SKU3  61.163343          68.0                       83
# 4      skincare   SKU4   4.805496          26.0                      871
# ..          ...    ...        ...           ...                      ...
# 95     haircare  SKU95  77.903927          65.0                      672
# 96    cosmetics  SKU96  24.423131          29.0                      324
# 97     haircare  SKU97   3.526111          56.0                       62
# 98     skincare  SKU98  19.754605          43.0                      913
# 99     haircare  SKU99  68.517833          17.0                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# ...

# %%
scmDataFm[scmDataFm["SKU"]=='SKU0']
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006           NaN                      802
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
#
#    Defect rates  Transportation modes   Routes       Costs
# 0       0.22641                  Road  Route B  187.752075
#
# [1 rows x 24 columns]

# %%
# calculating Not Null
scmDataFm[scmDataFm["Availability"].isnull()]
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006           NaN                      802
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
#
#    Defect rates  Transportation modes   Routes       Costs
# 0       0.22641                  Road  Route B  187.752075
#
# [1 rows x 24 columns]

# %%
## Transpose
scmDataFm1 = scmDataFm.T
scmDataFm1.head(5)
# Out:
#                                 0          1          2          3         4   \
# Product type              haircare   skincare   haircare   skincare  skincare
# SKU                           SKU0       SKU1       SKU2       SKU3      SKU4
# Price                    69.808006  14.843523  11.319683  61.163343  4.805496
# Availability                   NaN       95.0       34.0       68.0      26.0
# Number of products sold        802        736          8         83       871
#
#                                5         6          7          8          9   \
# Product type             haircare  skincare  cosmetics  cosmetics   skincare
# SKU                          SKU5      SKU6       SKU7       SKU8       SKU9
# Price                    1.699976  4.078333  42.958384  68.717597  64.015733
# Availability                 87.0      48.0       59.0       78.0       35.0
# Number of products sold       147        65        426        150        980
#
# ...

# %%
# scmDataFm.dropna(subset=["Number of products sold"],inplace=True)
# scmDataFm.head(100)
scmDataFm.rename(columns={'Product type':'Type of Product'},inplace=True)
scmDataFm.head(10)
# Out:
#   Type of Product   SKU      Price  Availability  Number of products sold  \
# 0        haircare  SKU0  69.808006           NaN                      802
# 1        skincare  SKU1  14.843523          95.0                      736
# 2        haircare  SKU2  11.319683          34.0                        8
# 3        skincare  SKU3  61.163343          68.0                       83
# 4        skincare  SKU4   4.805496          26.0                      871
# 5        haircare  SKU5   1.699976          87.0                      147
# 6        skincare  SKU6   4.078333          48.0                       65
# 7       cosmetics  SKU7  42.958384          59.0                      426
# 8       cosmetics  SKU8  68.717597          78.0                      150
# 9        skincare  SKU9  64.015733          35.0                      980
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# ...
