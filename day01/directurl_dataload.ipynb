# %%
pip install pandas

# %%
# Let check URL of the player stats in 2024
import pandas as pd

url = 'https://www.basketball-reference.com/leagues/NBA_2024.html'

# Using pd.read_html()

df = pd.read_html(url, header = 0)

print(df)
# Out:
# [          Eastern Conference   W   L   W/L%    GB   PS/G   PA/G    SRS
# 0        Boston Celtics* (1)  64  18  0.780     —  120.6  109.2  10.75
# 1       New York Knicks* (2)  50  32  0.610  14.0  112.8  108.2   4.36
# 2       Milwaukee Bucks* (3)  49  33  0.598  15.0  119.0  116.4   2.44
# 3   Cleveland Cavaliers* (4)  48  34  0.585  16.0  112.6  110.2   1.98
# 4         Orlando Magic* (5)  47  35  0.573  17.0  110.5  108.4   1.48
# 5        Indiana Pacers* (6)  47  35  0.573  17.0  123.3  120.2   2.75
# 6    Philadelphia 76ers* (7)  47  35  0.573  17.0  114.6  111.5   2.51
# 7            Miami Heat* (8)  46  36  0.561  18.0  110.1  108.4   1.10
# 8          Chicago Bulls (9)  39  43  0.476  25.0  112.3  113.7  -1.77
# 9         Atlanta Hawks (10)  36  46  0.439  28.0  118.3  120.5  -2.38
# 10        Brooklyn Nets (11)  32  50  0.390  32.0  110.4  113.3  -3.02
# 11      Toronto Raptors (12)  25  57  0.305  39.0  112.4  118.8  -6.45
# ...
